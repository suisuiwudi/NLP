# %%
import pickle 
train, test, dicts, aaa = pickle.load(open('dataset/atis.fold0.pkl', 'rb'), encoding='bytes')

# %%
print(train)
# Out:
# ([array([554, 194, 268,  64,  62,  16,   8, 234, 481,  20,  40,  58, 234,
#        415, 205], dtype=int32), array([554, 241, 481,  14, 200,  91,  26, 239], dtype=int32), array([232,   0, 273, 502, 254, 481, 165, 193, 208,  77, 502,  64],
#       dtype=int32), array([439, 301, 481, 532,  22, 194, 208,  64, 502,  77], dtype=int32), array([439, 301, 481,  99, 410, 516, 208, 128, 502,  69], dtype=int32), array([232,   0, 273, 502, 425,  32, 194, 208, 137, 502, 376], dtype=int32), array([177, 182, 111, 394], dtype=int32), array([232,   0, 273,  13, 530,  26, 193, 358, 546, 208, 415, 205, 502,
#         77], dtype=int32), array([554, 241, 481, 386, 353,  37,  26, 193,   9, 208, 332, 569, 502,
#        285,  41], dtype=int32), array([554, 157, 481, 302, 111, 411, 453, 200], dtype=int32), array([554,  50,  32, 194, 502, 137, 208, 376, 358, 463], dtype=int32), array([554, 501, 157, 481, 263,  20, 193, 268, 208, 543, 200, 137],
# ...

# %%
print(test)
# Out:
# ([array([554,  23, 241, 534, 358, 136, 193,  11, 208, 251, 104, 502, 413,
#        256, 104], dtype=int32), array([232, 542, 502, 213, 208,  77, 502,  64, 358, 317], dtype=int32), array([232, 331,  13, 193, 208,  64, 502, 376,  40, 232,   2, 284, 200,
#        481,  99, 182], dtype=int32), array([232, 331,  13, 193, 208, 506, 502, 319, 397, 319, 166, 358, 206],
#       dtype=int32), array([439, 301, 481, 174, 194, 208, 376, 502,  69], dtype=int32), array([473, 301, 154, 208, 367,  29, 502, 481, 104], dtype=int32), array([554, 241, 405,  47], dtype=int32), array([554, 241, 481, 288, 121, 182, 480, 136, 220,  73,  77,  40, 415,
#        205], dtype=int32), array([193,  10, 208, 102, 502, 128], dtype=int32), array([346, 232, 331,  13, 359, 544, 193, 208, 379, 502, 137], dtype=int32), array([153,  32, 194, 270, 208, 506, 502, 415, 147, 358, 532,  22,   7,
#        370, 234, 543, 132], dtype=int32), array([276,  32, 339, 194, 358, 518,  72, 341, 208,  97, 502,  69],
# ...

# %%
print(dicts)
# Out:
# ([array([232, 565, 273, 502, 189,  13, 193, 208,  97, 502, 260, 539, 480,
#        294,  13, 458, 234, 452, 286], dtype=int32), array([358,  49, 190, 232, 331,  13, 498, 208, 466, 502, 415, 247, 139,
#         72,   8,  35], dtype=int32), array([358,  49, 190, 232, 331,  13, 193, 215, 208, 378, 502, 415, 147],
#       dtype=int32), array([232, 565, 273,  13, 193, 514, 359, 544, 208, 378, 502, 415, 147,
#        358,  49, 190], dtype=int32), array([232, 565, 273,  13, 193, 208, 367, 502, 413, 256, 104, 200,  49,
#        190, 358, 136,  26], dtype=int32), array([232, 331,  13, 193, 208, 506, 502, 333, 359, 544, 270, 546, 174,
#        363, 496, 321], dtype=int32), array([317, 321, 232, 565, 273, 502, 196, 208, 114, 502, 236], dtype=int32), array([358, 546,  49, 443, 232, 565, 273, 502, 196, 208, 282,  71, 502,
#        114,  19,   8, 384], dtype=int32), array([ 19,   9, 384, 358, 546,  49, 443, 232, 565, 273, 502, 196, 208,
# ...

# %%
print(aaa)
# Out:
# {b'words2idx': {b'sundays': 464, b'kind': 252, b'thirtieth': 489, b'only': 360, b'cp': 125, b'sixteenth': 442, b'north': 343, b'more': 320, b'capacity': 92, b'dollars': 158, b'all': 32, b'stop': 458, b'than': 478, b'use': 533, b'connection': 118, b'm80': 292, b'lake': 256, b'same': 414, b'today': 503, b'weekday': 549, b'pittsburgh': 379, b'west': 552, b'six': 440, b'next': 334, b'as': 61, b'new': 332, b'orlando': 367, b'nashville': 328, b'memphis': 306, b'72s': 6, b'type': 526, b'up': 531, b'co': 109, b'far': 181, b'me': 301, b'twenty': 524, b'monday': 317, b'ten': 474, b'texas': 477, b'fit': 191, b'land': 257, b'offer': 354, b'provide': 388, b'breakfast': 80, b'charlotte': 97, b'airfare': 24, b'later': 264, b'possible': 385, b'mornings': 322, b'heading': 222, b"'ll": 1, b'arrivals': 57, b'dinner': 150, b'thrift': 494, b'first': 190, b'airlines': 26, b'connecting': 117, b'q': 390, b'arrange': 54, b'classes': 106, b'phoenix': 378, b'if': 233, b'for': 200, b'either': 172, b'options': 3
# ...
